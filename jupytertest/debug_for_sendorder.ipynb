# %%
import QAStrategy

# %%
from QAStrategy.qactabase import QAStrategyCTABase

# %%
class x(QAStrategyCTABase):
    def on_bar(self, data):
        
        print(data)

# %%
account = x(code= 'rb2005',frequence='1min', strategy_id='testfordebug4')
# Out:
# Create new Account

# %%
account.send_order('BUY','OPEN',3350, 1)
# Out:
# <class 'int'>
# QUANTAXIS>> ============ c91378f9-f987-4736-838b-bad3329e269b SEND ORDER ==================
# QUANTAXIS>> directionBUY offset OPEN price3350 volume1
# {'volume_long': 0, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 0, 'volume_short': 0}
# 下单成功 c91378f9-f987-4736-838b-bad3329e269b
# 全部成交 c91378f9-f987-4736-838b-bad3329e269b
# QUANTAXIS>> ['oL-C4w1HjuPRqTIRcZUyYR0QcLzo']

# %%
import json

# %%
bytes(json.dumps({'code':'rb2005','open': 3341, 'high': 3351, 'low': 3341, 'close': 3351, 'datetime':'2019-10-14 09:00:00:000000'}), encoding='utf-8')
# Out:
# b'{"code": "rb2005", "open": 3341, "high": 3351, "low": 3341, "close": 3351, "datetime": "2019-10-14 09:00:00:000000"}'

# %%
account.callback('a','b', 'c',b'{"code": "rb2005", "open": 3341, "high": 3351, "low": 3341, "close": 3351, "datetime": "2019-10-14 09:00:00:000000"}')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:969: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_nested_tuple(tup)
# QUANTAXIS>> 2019-10-13 10:12:09.197626 UPDATE ACCOUNT
#                                    open  high   low  close  volume
# datetime                   code
# 2019-10-14 09:00:00:000000 rb2005  3341  3351  3341   3351     NaN

# %%
account.send_order('SELL', 'CLOSE', 3352, 1)
# Out:
# <class 'int'>
# QUANTAXIS>> ============ c2b95936-585e-48ef-9170-d4621b8bc203 SEND ORDER ==================
# QUANTAXIS>> directionSELL offset CLOSE price3352 volume1
# {'volume_long': 1.0, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 1.0, 'volume_short': 0}
# 下单成功 c2b95936-585e-48ef-9170-d4621b8bc203
# 全部成交 c2b95936-585e-48ef-9170-d4621b8bc203
# {'volume_long': 2.0, 'volume_short': 0, 'volume_long_frozen': 1, 'volume_short_frozen': 0}
# QUANTAXIS>> ['oL-C4w1HjuPRqTIRcZUyYR0QcLzo']

# %%
account.positions.message
# Out:
# {'code': 'rb2005',
#  'instrument_id': 'rb2005',
#  'user_id': 'quantaxis',
#  'portfolio_cookie': 'portfolio',
#  'username': 'quantaxis',
#  'position_id': 'dd63df35-724d-4694-9985-1ed474132c89',
#  'account_cookie': 'quantaxis',
#  'frozen': {},
#  'name': None,
#  'spms_id': None,
#  'oms_id': None,
#  'market_type': 'future_cn',
#  'exchange_id': None,
#  'moneypreset': 100000,
#  'moneypresetLeft': 100020.0,
#  'lastupdatetime': '',
#  'volume_long_today': 0.0,
#  'volume_long_his': 0,
#  'volume_long': 0.0,
#  'volume_short_today': 0,
#  'volume_short_his': 0,
#  'volume_short': 0,
#  'volume_long_frozen_today': 0.0,
#  'volume_long_frozen_his': 0,
#  'volume_long_frozen': 0.0,
#  'volume_short_frozen_today': 0,
#  'volume_short_frozen_his': 0,
#  'volume_short_frozen': 0,
#  'margin_long': 0.0,
#  'margin_short': 0,
#  'margin': 0.0,
#  'position_price_long': 3350.0,
#  'position_cost_long': 16750.0,
#  'position_price_short': 0,
#  'position_cost_short': 0,
# ...

# %%
account.orders
# Out:
# {'ba2c5fc0-8bf7-4ebf-b6db-64abd1527325': {'account_cookie': 'testfordebug2',
#   'user_id': 'testfordebug2',
#   'instrument_id': 'rb2005',
#   'towards': 2,
#   'exchange_id': 'SHFE',
#   'order_time': '2019-10-13 10:10:34.308027',
#   'volume': 1.0,
#   'price': 3350.0,
#   'order_id': 'ba2c5fc0-8bf7-4ebf-b6db-64abd1527325',
#   'seqno': 1,
#   'direction': 'BUY',
#   'offset': 'OPEN',
#   'volume_orign': 1.0,
#   'price_type': 'LIMIT',
#   'limit_price': 3350.0,
#   'time_condition': 'GFD',
#   'volume_condition': 'ANY',
#   'insert_date_time': '2019-10-13 10:10:34.308027',
#   'exchange_order_id': 'ac8b8a3d-30cb-4871-b870-91f1b23a5bcb',
#   'status': 300,
#   'volume_left': 0.0,
#   'last_msg': '全部成交',
#   'topic': 'send_order'},
#  '9ee1e41c-6ee7-4229-b6ed-29e3d57c51c2': {'account_cookie': 'testfordebug2',
#   'user_id': 'testfordebug2',
#   'instrument_id': 'rb2005',
#   'towards': -3,
#   'exchange_id': 'SHFE',
#   'order_time': '2019-10-13 10:10:44.753856',
# ...

# %%
account.qifiacc.close_profit
# Out:
# 20.0

# %%
acc.bank_id
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-b7dbc424ae4b> in <module>
# ----> 1 acc.bank_id
#
# AttributeError: 'x' object has no attribute 'bank_id'

# %%
order = account.qifiacc.send_order(
    code=account.code, towards=-2, price=3850, amount=1, order_id='orx1')
# Out:
# {'volume_long': 0, 'volume_short': 0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 0, 'volume_short': 0}
# 下单成功 orx1

# %%
account.qifiacc.make_deal(order)
# Out:
# 全部成交 orx1

# %%
account.qifiacc.balance
# Out:
# 1000000.0

# %%
account.update_account()
# Out:
# QUANTAXIS>> 2019-10-13 10:32:15.482087 UPDATE ACCOUNT

# %%
account.positions.message
# Out:
# {'code': 'rb2005',
#  'instrument_id': 'rb2005',
#  'user_id': 'quantaxis',
#  'portfolio_cookie': 'portfolio',
#  'username': 'quantaxis',
#  'position_id': '35bc79fc-6ac1-439b-a03f-c391a78b37a3',
#  'account_cookie': 'quantaxis',
#  'frozen': {},
#  'name': None,
#  'spms_id': None,
#  'oms_id': None,
#  'market_type': 'future_cn',
#  'exchange_id': None,
#  'moneypreset': 100000,
#  'moneypresetLeft': 96535.0,
#  'lastupdatetime': '',
#  'volume_long_today': 0,
#  'volume_long_his': 0,
#  'volume_long': 0,
#  'volume_short_today': 1.0,
#  'volume_short_his': 0,
#  'volume_short': 1.0,
#  'volume_long_frozen_today': 0,
#  'volume_long_frozen_his': 0,
#  'volume_long_frozen': 0,
#  'volume_short_frozen_today': 0,
#  'volume_short_frozen_his': 0,
#  'volume_short_frozen': 0,
#  'margin_long': 0,
#  'margin_short': 3465.0,
#  'margin': 3465.0,
#  'position_price_long': 0,
#  'position_cost_long': 0,
#  'position_price_short': 3850.0,
#  'position_cost_short': 38500.0,
# ...

# %%
account.update_account()

# %%
account.positions.message
# Out:
# {'code': 'rb2005',
#  'instrument_id': 'rb2005',
#  'user_id': 'quantaxis',
#  'portfolio_cookie': 'portfolio',
#  'username': 'quantaxis',
#  'position_id': '35bc79fc-6ac1-439b-a03f-c391a78b37a3',
#  'account_cookie': 'quantaxis',
#  'frozen': {},
#  'name': None,
#  'spms_id': None,
#  'oms_id': None,
#  'market_type': 'future_cn',
#  'exchange_id': None,
#  'moneypreset': 100000,
#  'moneypresetLeft': 96535.0,
#  'lastupdatetime': '',
#  'volume_long_today': 0,
#  'volume_long_his': 0,
#  'volume_long': 0,
#  'volume_short_today': 1.0,
#  'volume_short_his': 0,
#  'volume_short': 2.0,
#  'volume_long_frozen_today': 0,
#  'volume_long_frozen_his': 0,
#  'volume_long_frozen': 0,
#  'volume_short_frozen_today': 1,
#  'volume_short_frozen_his': 0,
#  'volume_short_frozen': 1,
#  'margin_long': 0,
#  'margin_short': 3465.0,
#  'margin': 3465.0,
#  'position_price_long': 0,
#  'position_cost_long': 0,
#  'position_price_short': 3850.0,
#  'position_cost_short': 38500.0,
# ...

# %%
order = account.qifiacc.send_order(
    code=account.code, towards=3, price=3840, amount=1, order_id='orx1')
# Out:
# {'volume_long': 0, 'volume_short': 1.0, 'volume_long_frozen': 0, 'volume_short_frozen': 0}
# {'volume_long': 0, 'volume_short': 1.0}
# 下单成功 orx1

# %%
account.qifiacc.balance
# Out:
# 944770.0

# %%
account.positions.float_profit_long
# Out:
# -16750.0

# %%
account.positions.float_profit_short
# Out:
# -38500.0
